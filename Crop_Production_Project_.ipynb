# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinnicios1Santos/Data_Science/blob/main/Crop_Production_Project_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**PROJECT : CROP PRODUCTION - 1996 / 2021**

# %% [markdown]
# Sobre o conjunto:
#
# Conjunto de dados de produção de arroz, trigo e vegetais!
#
# Este conjunto de dados fornece um registro abrangente da produção agrícola anual, incluindo arroz, trigo e vegetais, abrangendo de 1996 a 2021.

# %%
#importando as libs

import pandas as pd
import statistics as sts
import seaborn as srn

# %%
#importando os dados do diretório do google drive

df = pd.read_csv('/content/drive/MyDrive/Data Science /Projetos/Crop Production 1996 a 2021/rice_ countries.csv')
df2 = pd.read_csv('/content/drive/MyDrive/Data Science /Projetos/Crop Production 1996 a 2021/world_food_production.csv')

# %%
df.head()
# Out:
#       Country   2020   2010   2000   1990
# 0       China  211.9  195.8  187.9  189.3
# 1       India  178.3  144.0  127.5  111.2
# 2  Bangladesh   54.9   50.1   37.6   26.8
# 3   Indonesia   54.6   59.3   51.9   45.2
# 4     Vietnam   42.8   40.0   32.5   19.2
